# %% [markdown]
# ### Youtube data analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("INvideos.csv",parse_dates=[1,5])

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  10L1hZ9qa58      17.14.11
# 2  N1vE8iiEg64      17.14.11
# 3  kJzGH0PVQHQ      17.14.11
# 4  il_pSa5l98w      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           24  2017-11-12T15:48:08.000Z
# 2           23  2017-11-12T07:08:48.000Z
# 3           24  2017-11-13T01:14:16.000Z
# 4           24  2017-11-10T04:29:50.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
df.shape
# Out:
# (37351, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  object
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  object
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df.drop(["title","tags","thumbnail_link","description"],axis=1,inplace=True)

# %%
df.head()
# Out:
#       video_id trending_date    channel_title  category_id  \
# 0  kzwfHumJyYc      17.14.11  Lokdhun Punjabi            1
# 1  10L1hZ9qa58      17.14.11             TFPC           24
# 2  N1vE8iiEg64      17.14.11      Eruma Saani           23
# 3  kJzGH0PVQHQ      17.14.11       Filmylooks           24
# 4  il_pSa5l98w      17.14.11         Dil Raju           24
#
#                publish_time    views  likes  dislikes  comment_count  \
# 0  2017-11-12T12:20:39.000Z  1096327  33966       798            882
# 1  2017-11-12T15:48:08.000Z   473988   2011       243            149
# 2  2017-11-12T07:08:48.000Z  1242680  70353      1624           2684
# 3  2017-11-13T01:14:16.000Z   464015    492       293             66
# 4  2017-11-10T04:29:50.000Z  6106669  98612      4185           4763
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0              False             False                   False
# 1              False             False                   False
# ...

# %%
df[:10:2]
# Out:
#       video_id trending_date    channel_title  category_id  \
# 0  kzwfHumJyYc      17.14.11  Lokdhun Punjabi            1
# 2  N1vE8iiEg64      17.14.11      Eruma Saani           23
# 4  il_pSa5l98w      17.14.11         Dil Raju           24
# 6  c64I9HNpiOY      17.14.11         T-Series           10
# 8  g8QsfJhFpjY      17.14.11        Jump Cuts           24
#
#                publish_time     views   likes  dislikes  comment_count  \
# 0  2017-11-12T12:20:39.000Z   1096327   33966       798            882
# 2  2017-11-12T07:08:48.000Z   1242680   70353      1624           2684
# 4  2017-11-10T04:29:50.000Z   6106669   98612      4185           4763
# 6  2017-11-11T06:14:19.000Z  10588371  132738      8812          10847
# 8  2017-11-12T04:30:01.000Z    969030   59798      1545           2404
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0              False             False                   False
# ...

# %%
df.iloc[0:5,0:7]
# Out:
#       video_id trending_date    channel_title  category_id  \
# 0  kzwfHumJyYc      17.14.11  Lokdhun Punjabi            1
# 1  10L1hZ9qa58      17.14.11             TFPC           24
# 2  N1vE8iiEg64      17.14.11      Eruma Saani           23
# 3  kJzGH0PVQHQ      17.14.11       Filmylooks           24
# 4  il_pSa5l98w      17.14.11         Dil Raju           24
#
#                publish_time    views  likes
# 0 2017-11-12 12:20:39+00:00  1096327  33966
# 1 2017-11-12 15:48:08+00:00   473988   2011
# 2 2017-11-12 07:08:48+00:00  1242680  70353
# 3 2017-11-13 01:14:16+00:00   464015    492
# 4 2017-11-10 04:29:50+00:00  6106669  98612

# %%
df.loc["10L1hZ9qa58",0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '10L1hZ9qa58'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-cbf01a60f187> in <module>
# ----> 1 df.loc["10L1hZ9qa58",0]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
df.head()
# Out:
#       video_id trending_date    channel_title  category_id  \
# 0  kzwfHumJyYc      17.14.11  Lokdhun Punjabi            1
# 1  10L1hZ9qa58      17.14.11             TFPC           24
# 2  N1vE8iiEg64      17.14.11      Eruma Saani           23
# 3  kJzGH0PVQHQ      17.14.11       Filmylooks           24
# 4  il_pSa5l98w      17.14.11         Dil Raju           24
#
#                publish_time    views  likes  dislikes  comment_count  \
# 0 2017-11-12 12:20:39+00:00  1096327  33966       798            882
# 1 2017-11-12 15:48:08+00:00   473988   2011       243            149
# 2 2017-11-12 07:08:48+00:00  1242680  70353      1624           2684
# 3 2017-11-13 01:14:16+00:00   464015    492       293             66
# 4 2017-11-10 04:29:50+00:00  6106669  98612      4185           4763
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0              False             False                   False
# 1              False             False                   False
# ...

# %%
df1=df.groupby("video_id").agg({"video_id":"count"})

# %%
df1.head()
# Out:
#              video_id
# video_id
# #NAME?            511
# #VALUE!             7
# -0N9r10xb_0         2
# -0WuM6ctLHg         3
# -0mcgX4ro7I         2

# %%
df1=df1.rename({"video_id":"count"},axis=1)
df1.head()
# Out:
#              count
# video_id
# #NAME?         511
# #VALUE!          7
# -0N9r10xb_0      2
# -0WuM6ctLHg      3
# -0mcgX4ro7I      2

# %%
df1.sort_values(by="count",ascending=False)[1:]
# Out:
#              count
# video_id
# rRr1qiJRsXk     16
# l7E0kTvARsA     14
# 1J76wN0TPI4     14
# bYSRPuDEnTg     13
# C1Pn5Ln1R4M     13
# ...            ...
# HF1kW3-3P9A      1
# HFEgXBxtRE4      1
# dpmkJOYSZwI      1
# HGej3-so7qs      1
# zzcAq02ncAE      1
#
# [16306 rows x 1 columns]

# %%
df_temp=df.set_index("video_id")
df_temp.head(5)
# Out:
#             trending_date    channel_title  category_id  \
# video_id
# kzwfHumJyYc      17.14.11  Lokdhun Punjabi            1
# 10L1hZ9qa58      17.14.11             TFPC           24
# N1vE8iiEg64      17.14.11      Eruma Saani           23
# kJzGH0PVQHQ      17.14.11       Filmylooks           24
# il_pSa5l98w      17.14.11         Dil Raju           24
#
#                          publish_time    views  likes  dislikes  \
# video_id
# kzwfHumJyYc 2017-11-12 12:20:39+00:00  1096327  33966       798
# 10L1hZ9qa58 2017-11-12 15:48:08+00:00   473988   2011       243
# N1vE8iiEg64 2017-11-12 07:08:48+00:00  1242680  70353      1624
# kJzGH0PVQHQ 2017-11-13 01:14:16+00:00   464015    492       293
# il_pSa5l98w 2017-11-10 04:29:50+00:00  6106669  98612      4185
#
#              comment_count  comments_disabled  ratings_disabled  \
# video_id
# kzwfHumJyYc            882              False             False
# 10L1hZ9qa58            149              False             False
# ...

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37351 entries, kzwfHumJyYc to wERgpPK44w0
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   trending_date           37351 non-null  object
#  1   channel_title           37351 non-null  object
#  2   category_id             37351 non-null  int64
#  3   publish_time            37351 non-null  datetime64[ns, UTC]
#  4   views                   37351 non-null  int64
#  5   likes                   37351 non-null  int64
#  6   dislikes                37351 non-null  int64
#  7   comment_count           37351 non-null  int64
#  8   comments_disabled       37351 non-null  bool
#  9   ratings_disabled        37351 non-null  bool
#  10  video_error_or_removed  37351 non-null  bool
# dtypes: bool(3), datetime64[ns, UTC](1), int64(5), object(2)
# memory usage: 3.9+ MB

# %%
#pd.to_datetime(df['trending_date'], format='%y.%m.%d')

pd.to_datetime(df['trending_date'], format= '%y.%d.%m')
# Out:
# 0       2017-11-14
# 1       2017-11-14
# 2       2017-11-14
# 3       2017-11-14
# 4       2017-11-14
#            ...
# 37346   2018-06-14
# 37347   2018-06-14
# 37348   2018-06-14
# 37349   2018-06-14
# 37350   2018-06-14
# Name: trending_date, Length: 37351, dtype: datetime64[ns]
