# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_excel("Youtube_data.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16307 entries, 0 to 16306
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              16307 non-null  int64
#  1   video_id                16307 non-null  object
#  2   trending_date           16307 non-null  datetime64[ns]
#  3   title                   16307 non-null  object
#  4   channel_title           16307 non-null  object
#  5   category_id             16307 non-null  int64
#  6   publish_date            16307 non-null  datetime64[ns]
#  7   views                   16307 non-null  int64
#  8   likes                   16307 non-null  int64
#  9   dislikes                16307 non-null  int64
#  10  comment_count           16307 non-null  int64
#  11  comments_disabled       16307 non-null  bool
#  12  ratings_disabled        16307 non-null  bool
#  13  video_error_or_removed  16307 non-null  bool
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0   category_id         views         likes      dislikes  \
# count  16307.000000  16307.000000  1.630700e+04  1.630700e+04  1.630700e+04
# mean    8153.000000     22.395352  6.835296e+05  1.444005e+04  9.571832e+02
# std     4707.569755      5.934638  2.363033e+06  6.687146e+04  1.264308e+04
# min        0.000000      1.000000  4.024000e+03  0.000000e+00  0.000000e+00
# 25%     4076.500000     23.000000  8.859200e+04  5.610000e+02  6.900000e+01
# 50%     8153.000000     24.000000  2.054880e+05  1.744000e+03  1.940000e+02
# 75%    12229.500000     25.000000  5.289405e+05  6.460000e+03  5.910000e+02
# max    16306.000000     43.000000  1.254322e+08  2.912710e+06  1.545017e+06
#
#        comment_count
# count   16307.000000
# mean     1481.797572
# std     10408.525506
# min         0.000000
# 25%        47.000000
# 50%       195.000000
# 75%       700.000000
# max    807558.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'video_id', 'trending_date', 'title', 'channel_title',
#        'category_id', 'publish_date', 'views', 'likes', 'dislikes',
#        'comment_count', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16307, step=1)

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                        int64
# publish_date              datetime64[ns]
# views                              int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# comments_disabled                   bool
# ratings_disabled                    bool
# video_error_or_removed              bool
# dtype: object

# %%
df.size
# Out:
# 228298

# %%
df.shape
# Out:
# (16307, 14)

# %%
df.isna().count()
# Out:
# Unnamed: 0                16307
# video_id                  16307
# trending_date             16307
# title                     16307
# channel_title             16307
# category_id               16307
# publish_date              16307
# views                     16307
# likes                     16307
# dislikes                  16307
# comment_count             16307
# comments_disabled         16307
# ratings_disabled          16307
# video_error_or_removed    16307
# dtype: int64

# %%
df.groupby(["category_id"]).head().sort_values(by=["category_id","views"],ascending=False)
# Out:
#      Unnamed: 0     video_id trending_date  \
# 115         115  AlrbKKGIcjI    2017-11-15
# 17           17  WPuhu6dYyQY    2017-11-14
# 310         310  5EBDXsTkg1E    2017-11-17
# 327         327  nMN7su1YHKo    2017-11-17
# 234         234  wX0P4YuMycA    2017-11-16
# ..          ...          ...           ...
# 21           21  xjFKfAudCOo    2017-11-14
# 95           95  1r4NI9_rC8A    2017-11-14
# 34           34  6I2yAoxBRtI    2017-11-14
# 37           37  7HTw1Jz5lcQ    2017-11-14
# 109         109  DckjtlTRxxw    2017-11-14
#
#                                                  title  \
# 115                  Deivamagal Episode 1388, 14/11/17
# 17   Baal Veer - बाल वीर - Episode 777 (Part 1) - 1...
# 310                 Priyamanaval Episode 866, 16/11/17
# 327  CID - सी आ डी - Episode 1225 - 15th November, ...
# 234  CID - सी आ डी - Episode 555 - 14th November, 2017
# ..                                                 ...
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0     video_id trending_date  \
# 0           0  Prb_osSVE0M    2017-11-14
# 1           1  1kuJkA9usqg    2017-11-14
# 2           2  znOC3IU0dF8    2017-11-14
#
#                                                title channel_title  \
# 0  Renu Desai Gives Rating For Pawan kalyan As Hu...    ABN Telugu
# 1                  Deivamagal Episode 1387, 13/11/17     VikatanTV
# 2  Hero Tarun at #ChaySamWeddingReception | Saman...   News Mantra
#
#    category_id publish_date   views  likes  dislikes  comment_count  \
# 0           25   2017-11-13  156085    716        53              0
# 1           24   2017-11-13  387221   2159      1214            711
# 2           24   2017-11-13   55178     45        94             15
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0               True             False                   False
# 1              False             False                   False
# ...

# %%
df.set_index("Unnamed: 0")
df.rename(columns={"Unnamed: 0":"id"})
# Out:
#           id     video_id trending_date  \
# 0          0  Prb_osSVE0M    2017-11-14
# 1          1  1kuJkA9usqg    2017-11-14
# 2          2  znOC3IU0dF8    2017-11-14
# 3          3  z3V9LUA6VQM    2017-11-14
# 4          4  gW4Su5wq0b8    2017-11-14
# ...      ...          ...           ...
# 16302  16302  iNHecA3PJCo    2018-06-14
# 16303  16303  dpPmPbhcslM    2018-06-14
# 16304  16304  mV6aztP58f8    2018-06-14
# 16305  16305  qxqDNP1bDEw    2018-06-14
# 16306  16306  wERgpPK44w0    2018-06-14
#
#                                                    title       channel_title  \
# 0      Renu Desai Gives Rating For Pawan kalyan As Hu...          ABN Telugu
# 1                      Deivamagal Episode 1387, 13/11/17           VikatanTV
# 2      Hero Tarun at #ChaySamWeddingReception | Saman...         News Mantra
# 3      ఆమె బ్యాంకు అకౌంట్ లో పొరపాటున 125 కోట్లు జమయా...               OmFut
# 4             Neeya Naana - 12th November 2017 - Promo 2    Vijay Television
# ...

# %%
df.loc[0:,["video_id","publish_date","channel_title","views"]].sort_values(by="views",ascending=False).groupby("publish_date").head()
# Out:
#           video_id publish_date  \
# 2497   FlsCjmMhFmw   2017-12-06
# 2067   6ZfuNTqbHE8   2017-11-29
# 13371  u9Mv98Gr5pY   2018-04-24
# 10943  QwievZ1Tx-8   2018-03-16
# 13522  rRr1qiJRsXk   2018-04-24
# ...            ...          ...
# 12064  e7E7Jj1yLuA   2018-04-07
# 12141  jGcSjkFbY5s   2018-04-06
# 12183  y2OiVBFKuSI   2018-04-06
# 4589   T85l5uiBz1U   2017-05-27
# 12107  _ZZb4w9ed8w   2018-04-07
#
#                                            channel_title      views
# 2497                                   YouTube Spotlight  125432237
# 2067                                Marvel Entertainment   89930713
# 13371                        Sony Pictures Entertainment   53822757
# 10943                               Marvel Entertainment   45064699
# 13522                                       FoxStarHindi   44171797
# ...                                                  ...        ...
# 12064                                                WWE     563675
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0     video_id trending_date  \
# 0           0  Prb_osSVE0M    2017-11-14
# 1           1  1kuJkA9usqg    2017-11-14
# 2           2  znOC3IU0dF8    2017-11-14
#
#                                                title channel_title  \
# 0  Renu Desai Gives Rating For Pawan kalyan As Hu...    ABN Telugu
# 1                  Deivamagal Episode 1387, 13/11/17     VikatanTV
# 2  Hero Tarun at #ChaySamWeddingReception | Saman...   News Mantra
#
#    category_id publish_date   views  likes  dislikes  comment_count  \
# 0           25   2017-11-13  156085    716        53              0
# 1           24   2017-11-13  387221   2159      1214            711
# 2           24   2017-11-13   55178     45        94             15
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0               True             False                   False
# 1              False             False                   False
# ...

# %%
df1=df[["video_id","publish_date","trending_date","channel_title","views","likes","dislikes","comment_count"]]
df1.head(3)
# Out:
#       video_id publish_date trending_date channel_title   views  likes  \
# 0  Prb_osSVE0M   2017-11-13    2017-11-14    ABN Telugu  156085    716
# 1  1kuJkA9usqg   2017-11-13    2017-11-14     VikatanTV  387221   2159
# 2  znOC3IU0dF8   2017-11-13    2017-11-14   News Mantra   55178     45
#
#    dislikes  comment_count
# 0        53              0
# 1      1214            711
# 2        94             15

# %%
df1.dtypes
# Out:
# video_id                 object
# publish_date     datetime64[ns]
# trending_date    datetime64[ns]
# channel_title            object
# views                     int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# dtype: object

# %%
df1.groupby(["trending_date","video_id"]).head()
# Out:
#           video_id publish_date trending_date       channel_title    views  \
# 0      Prb_osSVE0M   2017-11-13    2017-11-14          ABN Telugu   156085
# 1      1kuJkA9usqg   2017-11-13    2017-11-14           VikatanTV   387221
# 2      znOC3IU0dF8   2017-11-13    2017-11-14         News Mantra    55178
# 3      z3V9LUA6VQM   2017-11-12    2017-11-14               OmFut   236710
# 4      gW4Su5wq0b8   2017-11-11    2017-11-14    Vijay Television   261202
# ...            ...          ...           ...                 ...      ...
# 16302  iNHecA3PJCo   2018-06-13    2018-06-14      RDC Rajasthani   214378
# 16303  dpPmPbhcslM   2018-06-13    2018-06-14          Flowers TV   406828
# 16304  mV6aztP58f8   2018-06-13    2018-06-14   Mazhavil Manorama   386319
# 16305  qxqDNP1bDEw   2018-06-13    2018-06-14           Tarang TV   130263
# 16306  wERgpPK44w0   2018-06-10    2018-06-14  Suresh Productions  1278249
#
#        likes  dislikes  comment_count
# ...

# %%
df2=df1.groupby(["channel_title"]).agg({"trending_date":"count"})

# %%
df2.head()
# Out:
#                         trending_date
# channel_title
# #Mind Warehouse                     1
# 1 Kg Biriyani                      18
# 1 Minutes news                      5
# 10 DEGREE INDIAN FACTS             15
# 10TVNewsChannel                     7

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1422 entries, #Mind Warehouse to വിശ്വാസം അതല്ലേ എല്ലാം
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   trending_date  1422 non-null   int64
# dtypes: int64(1)
# memory usage: 22.2+ KB

# %%
df2.sort_values(by="trending_date",ascending=False).head(20)
# Out:
#                                                     trending_date
# channel_title
# Study IQ education                                            169
# Tarang TV                                                     158
# etvteluguindia                                                153
# VikatanTV                                                     153
# Saregama TVShows                                              152
# Mazhavil Manorama                                             138
# RadaanMedia                                                   136
# zeemarathi                                                    135
# zeetvtelugu                                                   134
# Colors TV                                                     130
# SAB TV                                                        130
# ETV Plus India                                                129
# ETV Andhra Pradesh                                            123
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0     video_id trending_date  \
# 0           0  Prb_osSVE0M    2017-11-14
# 1           1  1kuJkA9usqg    2017-11-14
# 2           2  znOC3IU0dF8    2017-11-14
#
#                                                title channel_title  \
# 0  Renu Desai Gives Rating For Pawan kalyan As Hu...    ABN Telugu
# 1                  Deivamagal Episode 1387, 13/11/17     VikatanTV
# 2  Hero Tarun at #ChaySamWeddingReception | Saman...   News Mantra
#
#    category_id publish_date   views  likes  dislikes  comment_count  \
# 0           25   2017-11-13  156085    716        53              0
# 1           24   2017-11-13  387221   2159      1214            711
# 2           24   2017-11-13   55178     45        94             15
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0               True             False                   False
# 1              False             False                   False
# ...

# %%
df=df.rename(columns={"Unnamed: 0":"id"})
df=df.set_index("id")
df.head()
# Out:
#        video_id trending_date  \
# id
# 0   Prb_osSVE0M    2017-11-14
# 1   1kuJkA9usqg    2017-11-14
# 2   znOC3IU0dF8    2017-11-14
# 3   z3V9LUA6VQM    2017-11-14
# 4   gW4Su5wq0b8    2017-11-14
#
#                                                 title     channel_title  \
# id
# 0   Renu Desai Gives Rating For Pawan kalyan As Hu...        ABN Telugu
# 1                   Deivamagal Episode 1387, 13/11/17         VikatanTV
# 2   Hero Tarun at #ChaySamWeddingReception | Saman...       News Mantra
# 3   ఆమె బ్యాంకు అకౌంట్ లో పొరపాటున 125 కోట్లు జమయా...             OmFut
# 4          Neeya Naana - 12th November 2017 - Promo 2  Vijay Television
#
#     category_id publish_date   views  likes  dislikes  comment_count  \
# id
# 0            25   2017-11-13  156085    716        53              0
# 1            24   2017-11-13  387221   2159      1214            711
# 2            24   2017-11-13   55178     45        94             15
# ...

# %%
df.groupby("category_id").agg({"video_id":"count"})
# Out:
#              video_id
# category_id
# 1                 523
# 2                  34
# 10               1213
# 15                  1
# 17                347
# 19                  4
# 20                 20
# 22               1232
# 23               1114
# 24               7547
# 25               2505
# 26                478
# 27                797
# 28                300
# 29                 69
# 30                  2
# 43                121

# %%
df.groupby(["channel_title","category_id"]).agg({"video_id":"count"})
# Out:
#                                     video_id
# channel_title          category_id
# #Mind Warehouse        27                  1
# 1 Kg Biriyani          23                 18
# 1 Minutes news         25                  5
# 10 DEGREE INDIAN FACTS 24                 15
# 10TVNewsChannel        25                  7
# ...                                      ...
# भक्ति                  27                  1
# वास्तु उपाय            22                  4
# জীবন-সমস্যার সমাধান    27                  1
# ഖല്‍ബാണ് ലീഗ്          22                  1
# വിശ്വാസം അതല്ലേ എല്ലാം 24                  5
#
# [1652 rows x 1 columns]

# %%
df.groupby("year").agg({"year":"count"})
# Out:
#        year
# year
# 2017   4538
# 2018  11769

# %%
df.groupby([df["publish_date"].dt.month])
df["month"]=df["publish_date"].dt.month

# %%
df.head(2)
# Out:
#        video_id trending_date  \
# id
# 0   Prb_osSVE0M    2017-11-14
# 1   1kuJkA9usqg    2017-11-14
#
#                                                 title channel_title  \
# id
# 0   Renu Desai Gives Rating For Pawan kalyan As Hu...    ABN Telugu
# 1                   Deivamagal Episode 1387, 13/11/17     VikatanTV
#
#     category_id publish_date   views  likes  dislikes  comment_count  \
# id
# 0            25   2017-11-13  156085    716        53              0
# 1            24   2017-11-13  387221   2159      1214            711
#
#     comments_disabled  ratings_disabled  video_error_or_removed  year  month
# id
# 0                True             False                   False  2017     11
# 1               False             False                   False  2017     11

# %%
df5=df[["video_id","channel_title","month","year"]]

# %%
df5.head()
# Out:
#        video_id     channel_title  month  year
# id
# 0   Prb_osSVE0M        ABN Telugu     11  2017
# 1   1kuJkA9usqg         VikatanTV     11  2017
# 2   znOC3IU0dF8       News Mantra     11  2017
# 3   z3V9LUA6VQM             OmFut     11  2017
# 4   gW4Su5wq0b8  Vijay Television     11  2017

# %%
df5=df5.loc[df["year"]==2018]
df5.head()
# Out:
#          video_id       channel_title  month  year
# id
# 4415  hUpY27L0wQQ   YOYO Cine Talkies      1  2018
# 4416  XZ1aY82cD5o         Gusa Gusalu      1  2018
# 4417  QXLsIfTwm_A  Study IQ education      1  2018
# 4420  6e0XqZK4nNM           Tarang TV      1  2018
# 4424  2oEmJAAKh9I           FilmiBeat      1  2018

# %%
df5.groupby(["month"]).agg({"month":"count"})
# Out:
#        month
# month
# 1       2644
# 2       2258
# 3       2340
# 4       1685
# 5       2018
# 6        824
